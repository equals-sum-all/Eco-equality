# %% [markdown]
# <a href="https://colab.research.google.com/github/Jojomaque/Eco-equality/blob/main/Code/Project_Ed_Bike_Share_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load libraries
import pandas as pd
import holoviews as hv
from holoviews import opts, dim
from bokeh.sampledata.les_mis import data
import seaborn as sns  # plot handling
import matplotlib.pyplot as plt  # plot handling
import folium

hv.extension('bokeh')
hv.output(size=200)
# Out:
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# Load Data
january = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2021/01.csv')
february = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2021/02.csv')
march = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2021/03.csv')
april = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2021/04.csv')
may = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2021/05.csv')
june = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2021/06.csv')

# %%
Ed_Bike_2021 = pd.concat([january, february, march, april, may, june])
Ed_Bike_2021.tail()
# Out:
#                              started_at  ... end_station_longitude
# 12636  2021-06-30 23:30:31.097000+00:00  ...             -3.118332
# 12637  2021-06-30 23:36:16.766000+00:00  ...             -3.118332
# 12638  2021-06-30 23:49:03.148000+00:00  ...             -3.180413
# 12639  2021-06-30 23:49:03.250000+00:00  ...             -3.180413
# 12640  2021-06-30 23:58:33.482000+00:00  ...             -3.180986
#
# [5 rows x 13 columns]

# %%
Ed_Bike_2021.end_station_name.nunique()
# Out:
# 98

# %%
journeys = Ed_Bike_2021[['start_station_name','end_station_name']].value_counts()
journey_count = journeys.to_frame().reset_index()
journey_count.rename(columns = {0:'journeys'}, inplace = True)
journey_count
# Out:
#                      start_station_name          end_station_name  journeys
# 0               Portobello - Kings Road   Portobello - Kings Road       761
# 1                         Pollock Halls   Portobello - Kings Road       662
# 2                     Cramond Foreshore         Cramond Foreshore       636
# 3                         Victoria Quay             Victoria Quay       546
# 4               Portobello - Kings Road               Duke Street       411
# ...                                 ...                       ...       ...
# 5729  Kings Buildings - Murchison House        South Trinity Road         1
# 5730  Kings Buildings - Murchison House              Simon Square         1
# 5731  Kings Buildings - Murchison House  Royal Edinburgh Hospital         1
# 5732  Kings Buildings - Murchison House       Pleasance Courtyard         1
# 5733                      Hunter Square          Murrayfield Tram         1
#
# [5734 rows x 3 columns]

# %%
top_journey = journey_count[:20]
top_journey
# Out:
#          start_station_name         end_station_name  journeys
# 0   Portobello - Kings Road  Portobello - Kings Road       761
# 1             Pollock Halls  Portobello - Kings Road       662
# 2         Cramond Foreshore        Cramond Foreshore       636
# 3             Victoria Quay            Victoria Quay       546
# 4   Portobello - Kings Road              Duke Street       411
# 5             Dynamic Earth            Dynamic Earth       392
# 6              Meadows East             Meadows East       386
# 7              Meadow Place             Meadow Place       383
# 8             Pollock Halls            Pollock Halls       367
# 9                Canonmills               Canonmills       363
# 10              Duke Street              Duke Street       341
# 11            Dynamic Earth  Portobello - Kings Road       324
# 12             Meadows East  Portobello - Kings Road       311
# 13             Meadow Place  Portobello - Kings Road       288
# ...

# %%
names = top_journey.start_station_name + '/' + top_journey.end_station_name
plt.figure(figsize=(12,10))
sns.barplot( x=top_journey.journeys[:60], y=names, orient="h")

# %%
pip install holoviews

# %%
pd.pivot_table(top_journey,index='start_station_name',values='journeys',columns='end_station_name')
# Out:
# end_station_name         Canonmills  ...  Victoria Quay
# start_station_name                   ...
# Bruntsfield Links               NaN  ...            NaN
# Canonmills                    363.0  ...            NaN
# Cramond Foreshore               NaN  ...            NaN
# Duke Street                     NaN  ...            NaN
# Dynamic Earth                   NaN  ...            NaN
# Meadow Place                    NaN  ...            NaN
# Meadows East                    NaN  ...            NaN
# Pollock Halls                   NaN  ...            NaN
# Portobello - Kings Road         NaN  ...          209.0
# Victoria Quay                   NaN  ...          546.0
#
# [10 rows x 9 columns]

# %%
chord=hv.Chord(journey_count[:50])
chord.opts(node_color='index', edge_color='start_station_name',\
label_index='index',cmap='Category20', edge_cmap='Category20' )
# Out:
# :Chord   [start_station_name,end_station_name]   (journeys)

# %%
least_journey = journey_count[-20:]
least_journey
# Out:
#                      start_station_name           end_station_name  journeys
# 5714                      Colinton Road  Edinburgh Royal Infirmary         1
# 5715                      City Chambers       Waitrose Comely Bank         1
# 5716                  Kings Buildings 1            Brunswick Place         1
# 5717                  Kings Buildings 1              McDonald Road         1
# 5718                  Kings Buildings 1              Hunter Square         1
# 5719                  Kings Buildings 1              Holyrood Road         1
# 5720                  Kings Buildings 1             Dundee Terrace         1
# 5721                  Kings Buildings 1              Dundas Street         1
# 5722                  Kings Buildings 1                Duke Street         1
# 5723                  Kings Buildings 1              Castle Street         1
# 5724  Kings Buildings - Murchison House                  Tollcross         1
# ...
