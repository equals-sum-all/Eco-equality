# %% [markdown]
# <a href="https://colab.research.google.com/github/Jojomaque/Eco-equality/blob/main/Code/Project_Ed_Bike_Share_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load libraries
import pandas as pd
import holoviews as hv
from holoviews import opts, dim
from bokeh.sampledata.les_mis import data
import seaborn as sns  # plot handling
import matplotlib.pyplot as plt  # plot handling
import folium

hv.extension('bokeh')
hv.output(size=200)
# Out:
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# Load Data
january = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2019/01.csv')
february = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2019/02.csv')
march = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2019/03.csv')
april = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2019/04.csv')
may = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2019/05.csv')
june = pd.read_csv('https://data.urbansharing.com/edinburghcyclehire.com/trips/v1/2019/06.csv')

# %%
Ed_Bike_2019 = pd.concat([january, february, march, april, may, june])
Ed_Bike_2019.tail()
# Out:
#                              started_at  ... end_station_longitude
# 10591  2019-06-30 23:36:11.370000+00:00  ...             -3.196284
# 10592  2019-06-30 23:41:22.064000+00:00  ...             -3.203184
# 10593  2019-06-30 23:49:48.425000+00:00  ...             -3.203184
# 10594  2019-06-30 23:50:34.486000+00:00  ...             -3.203184
# 10595  2019-06-30 23:51:09.789000+00:00  ...             -3.185189
#
# [5 rows x 13 columns]

# %%
journeys = Ed_Bike_2019[['start_station_name','end_station_name']].value_counts()
journey_count = journeys.to_frame().reset_index()
journey_count.rename(columns = {0:'journeys'}, inplace = True)
journey_count
# Out:
#      start_station_name              end_station_name  journeys
# 0            Portobello                    Portobello       957
# 1            Canonmills                    Canonmills       298
# 2            Canonmills                 Victoria Quay       244
# 3        Fountainbridge                Fountainbridge       233
# 4      St Andrew Square                    Canonmills       231
# ...                 ...                           ...       ...
# 4157   Dalry Road Co-op              Murrayfield Tram         1
# 4158        Murrayfield  Corstorphine Road - Pinkhill         1
# 4159        Murrayfield              Comely Bank Road         1
# 4160        Murrayfield                 Colinton Road         1
# 4161  Cramond Foreshore            East London Street         1
#
# [4162 rows x 3 columns]

# %%
top_journey = journey_count[:20]
top_journey
# Out:
#    start_station_name   end_station_name  journeys
# 0          Portobello         Portobello       957
# 1          Canonmills         Canonmills       298
# 2          Canonmills      Victoria Quay       244
# 3      Fountainbridge     Fountainbridge       233
# 4    St Andrew Square         Canonmills       231
# 5         Newkirkgate        Newkirkgate       226
# 6      Ocean Terminal     Ocean Terminal       201
# 7       Victoria Quay         Canonmills       194
# 8        Meadows East       Meadows East       189
# 9          Canonmills     Dudley Gardens       183
# 10        Bruntsfield      George Square       180
# 11      Victoria Quay      Victoria Quay       180
# 12        Newkirkgate         Portobello       172
# 13    Lauriston Place       Meadows East       170
# 14       Meadows East     Dundee Terrace       165
# 15         Portobello        Newkirkgate       159
# 16      George Square      George Square       155
# ...

# %%
names = top_journey.start_station_name + '/' + top_journey.end_station_name
plt.figure(figsize=(12,10))
sns.barplot( x=top_journey.journeys[:20], y=names, orient="h")

# %%
pd.pivot_table(top_journey,index='start_station_name',values='journeys',columns='end_station_name')
# Out:
# end_station_name    Bristo Square  Canonmills  ...  Portobello  Victoria Quay
# start_station_name                             ...
# Bristo Square               153.0         NaN  ...         NaN            NaN
# Bruntsfield                   NaN         NaN  ...         NaN            NaN
# Canonmills                    NaN       298.0  ...         NaN          244.0
# Cramond Foreshore             NaN         NaN  ...         NaN            NaN
# Fountainbridge                NaN         NaN  ...         NaN            NaN
# George Square                 NaN         NaN  ...         NaN            NaN
# Lauriston Place               NaN         NaN  ...         NaN            NaN
# Meadows East                  NaN         NaN  ...         NaN            NaN
# Newkirkgate                   NaN         NaN  ...       172.0            NaN
# Ocean Terminal                NaN         NaN  ...         NaN            NaN
# ...

# %%
chord=hv.Chord(journey_count[:50])
chord.opts(node_color='index', edge_color='start_station_name',\
label_index='index',cmap='Category20', edge_cmap='Category20' )
# Out:
# :Chord   [start_station_name,end_station_name]   (journeys)

# %%
least_journey = journey_count[-20:]
least_journey
# Out:
#      start_station_name              end_station_name  journeys
# 4142   Morningside Road            South Trinity Road         1
# 4143   Dalry Road Co-op            South Trinity Road         1
# 4144   Dalry Road Co-op       Royal Commonwealth Pool         1
# 4145   Dalry Road Co-op                Dudley Gardens         1
# 4146   Dalry Road Co-op              Logie Green Road         1
# 4147        Murrayfield             St. John's Road 1         1
# 4148        Murrayfield              St Andrew Square         1
# 4149   Dalry Road Co-op                          EICC         1
# 4150   Dalry Road Co-op              Kings Building 2         1
# 4151        Murrayfield                  Meadow Place         1
# 4152        Murrayfield                Macdonald Road         1
# 4153        Murrayfield                Dudley Gardens         1
# 4154        Murrayfield                   Bruntsfield         1
# 4155        Murrayfield               Dalry Road Lidl         1
# ...
